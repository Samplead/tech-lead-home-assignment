# %% [markdown]
# #### **Appendix 2** to Samplead hometask
#
#
# *   This notebook is an **example** to the functionality of the **pos_tagging** function
# *   **You can use parts of this code** in your task, but you shold notice that some changes need to be done for you to be able to **serve this function**

# %%
# hint! this cell should help you to bulid the requirements.txt file
# install dependencies & download model

# !pip install spacy==3.4.1
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.0/en_core_web_sm-3.4.0.tar.gz#egg=en_core_web_sm
# !git clone https://github.com/Samplead/fullstack-hometask.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 919.6/919.6 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 33.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.12.3
#     Uninstalling typer-0.12.3:
#       Successfully uninstalled typer-0.12.3
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 7.0.4
#     Uninstalling smart-open-7.0.4:
#       Successfully uninstalled smart-open-7.0.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.7.3
# ...

# %%
# This is the function ⬇️ ⬇️ ⬇️

import spacy
spacy_pipeline = spacy.load("en_core_web_sm", disable = ['parser','lemmatizer'])

def pos_tagging(name,description):
  processed_text = spacy_pipeline(description)
  tagged_text = " ".join([token.pos_ for token in processed_text])
  return name.upper() + " || " + tagged_text

# %%
# usage example
ExampleRow = {"Name":"jeremy maxwell",
              "Description":"I am an experienced chief security officer with mastery in application security, compliance, and communication skills."}


pos_tagging(ExampleRow["Name"],ExampleRow["Description"])
# Out:
# 'JEREMY MAXWELL || PRON AUX DET ADJ ADJ NOUN NOUN ADP NOUN ADP NOUN NOUN PUNCT NOUN PUNCT CCONJ NOUN NOUN PUNCT'

# %%
import pandas as pd
# demo input
df = pd.read_csv('/content/fullstack-hometask/data/demo_input.csv')
df
# Out:
#                 Name                                        Description
# 0         Doug Kirby   you are a cybersecurity officer with skills i...
# 1        Jacob Zhang   you are a highly skilled and dedicated direct...
# 2      Chris Woodson   you are a highly skilled and dedicated manage...
# 3     Allison Winter   you are a highly skilled enterprise data and ...
# 4       Scott Willis   you are a highly skilled IT director with a k...
# 5   Matthew Williams   you are a highly skilled IT director with a k...
# 6          Jane Vong   you are a highly skilled IT security professi...
# 7     Justin Vaughan   you are a talented and dedicated information ...
# 8     Scott Valliani   you are a talented IT director who is skilled...
# 9       Linda Carter   you are an experienced IT project manager wit...
# 10     Michael Adams   you are a seasoned cybersecurity analyst with...
# 11        Emily Chen   you are a detail-oriented information securit...
# ...

# %%
import pandas as pd
# output
df['output'] = df.apply(lambda row: pos_tagging(row["Name"],row["Description"]), axis=1)
df
# Out:
#                 Name                                        Description  \
# 0         Doug Kirby   you are a cybersecurity officer with skills i...
# 1        Jacob Zhang   you are a highly skilled and dedicated direct...
# 2      Chris Woodson   you are a highly skilled and dedicated manage...
# 3     Allison Winter   you are a highly skilled enterprise data and ...
# 4       Scott Willis   you are a highly skilled IT director with a k...
# 5   Matthew Williams   you are a highly skilled IT director with a k...
# 6          Jane Vong   you are a highly skilled IT security professi...
# 7     Justin Vaughan   you are a talented and dedicated information ...
# 8     Scott Valliani   you are a talented IT director who is skilled...
# 9       Linda Carter   you are an experienced IT project manager wit...
# 10     Michael Adams   you are a seasoned cybersecurity analyst with...
# 11        Emily Chen   you are a detail-oriented information securit...
# ...
